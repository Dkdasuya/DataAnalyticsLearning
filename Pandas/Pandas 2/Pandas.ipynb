# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("Sacramentorealestatetransactions.csv",nrows = 10,na_values=["n.a.","not available"])
#df[df['price']<0]=0  #if any element in the price column is less then 0 then it is replaced by 0.THis will change all the values of the row as 0.\
df
# Out:
#                             street            city    zip state  beds  baths  \
# 0                     3526 HIGH ST      SACRAMENTO  95838    CA   2.0      1
# 1                      51 OMAHA CT      SACRAMENTO  95823    CA   3.0      1
# 2                   2796 BRANCH ST      SACRAMENTO  95815    CA   NaN      1
# 3                 2805 JANETTE WAY      SACRAMENTO  95815    CA   2.0      1
# 4                  6001 MCMAHON DR      SACRAMENTO  95824    CA   2.0      1
# 5               5828 PEPPERMILL CT      SACRAMENTO  95841    CA   3.0      1
# 6              6048 OGDEN NASH WAY      SACRAMENTO  95842   NaN   3.0      2
# 7                    2561 19TH AVE      SACRAMENTO  95820    CA   3.0      1
# 8  11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670    CA   2.0      2
# 9                     7325 10TH ST       RIO LINDA  95673    CA   3.0      2
#
#    sq__ft         type                     sale_date  price   latitude  \
# ...

# %%
plt.plot(df['sq__ft'],df['price'],marker="*")

# %%
df1 = pd.read_csv("Sacramentorealestatetransactions.csv",usecols=['street','city','zip','state','beds','baths'],nrows=10,na_values={
    'state':['n.a.'],
    'type':['not available'],
    'sq__ft':[0],
    'beds':['not available']
})

df1
# Out:
#                             street            city    zip state  beds  baths
# 0                     3526 HIGH ST      SACRAMENTO  95838    CA   2.0      1
# 1                      51 OMAHA CT      SACRAMENTO  95823    CA   3.0      1
# 2                   2796 BRANCH ST      SACRAMENTO  95815    CA   NaN      1
# 3                 2805 JANETTE WAY      SACRAMENTO  95815    CA   2.0      1
# 4                  6001 MCMAHON DR      SACRAMENTO  95824    CA   2.0      1
# 5               5828 PEPPERMILL CT      SACRAMENTO  95841    CA   3.0      1
# 6              6048 OGDEN NASH WAY      SACRAMENTO  95842   NaN   3.0      2
# 7                    2561 19TH AVE      SACRAMENTO  95820    CA   3.0      1
# 8  11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670    CA   2.0      2
# 9                     7325 10TH ST       RIO LINDA  95673    CA   3.0      2

# %%
df1.to_csv("new_csv.csv",index=False)

# %%
df1.to_csv("new_csv.csv",columns=['street','city','zip','beds','baths','sq__ft','type','price'])

# %%
def convert_price_cell(cell):
    if(cell<0):
        return 0
    return cell
excelDF = pd.read_excel("SomeData.xlsx","Sheet1",converters={
    'price': convert_price_cell
},nrows=3)
excelDF[['street','price']]
# Out:
#            street  price
# 0    3526 HIGH ST  59222
# 1     51 OMAHA CT  68212
# 2  2796 BRANCH ST  68880
